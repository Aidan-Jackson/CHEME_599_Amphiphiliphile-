# %% [markdown]
# Please make sure that you are the directory above the 'amph' package directory.

# %%
#Imports the entire package named 'amph'.
import amph as amph

# %%
#Imports the module 'miwa' and renames it
from amph import miwa as miwamethod

# %%
#Imports a single desired function
from amph import miwa_blob_detection
from amph import blobs

# %%
#Uses the function 'miwa_blob_detection'
image_name='t01.jpg'
miwa_blob_detection(image_name)
# Out:
# C:\Users\bubbl\Anaconda3\envs\py36\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# The number of detected blobs is 43.
# The average diameter of these blobs is 27.8.
