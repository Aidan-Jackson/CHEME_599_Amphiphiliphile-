# %% [markdown]
# In this notebook, I will demonstrate a workflow for my project.  First, I import an image with bright dots that need detecting

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('t01.tif')[:,:,0]*7
plt.imshow(img,cmap='gray')

# %% [markdown]
# Next, I will import 1 function for detecting those bright spots.  I will also use this function on my image

# %%
from find_bright_spots import find_bright_spots
find_bright_spots(img,lower = 0.8, upper = 0.1)
# Out:
# 'number of aqeous drops detected= 71'
